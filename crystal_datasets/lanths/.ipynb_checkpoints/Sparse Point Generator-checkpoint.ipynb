# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
AE = np.load('tsne.npy', allow_pickle = True)

# %%
AE
# Out:
# array([[ 14.9720545 ,  -2.303326  ],
#        [  5.164504  ,  -5.0427413 ],
#        [  5.033631  ,  -4.5090213 ],
#        ...,
#        [  9.150324  ,   0.35594982],
#        [-13.651211  ,  -5.8485384 ],
#        [-13.272702  ,  -5.4735527 ]], dtype=float32)

# %%
dist = np.linalg.norm(AE - AE[:,None], axis=-1)

# %%
dist.shape
# Out:
# (4166, 4166)

# %%
mean_dist = np.mean(dist, axis = 1)

# %%
mean_dist
# Out:
# array([17.34948 , 12.2769  , 12.070046, ..., 13.176003, 17.113909,
#        16.720924], dtype=float32)

# %%
arg_m = np.argmax(mean_dist)

# %%
sparest = dist[arg_m]

# %%
sparest
# Out:
# array([31.333513 , 21.402308 , 21.279184 , ..., 25.964512 ,  2.6969771,
#         2.9904494], dtype=float32)

# %%
max_min = sparest.argsort()[-18928:][::-1]

# %%
sparest[max_min[-5]]
# Out:
# 0.091843426

# %%
idx_sparse = mean_dist.argsort()[-1152:][::-1]

# %%
arg_m
# Out:
# 3901

# %%
sparest[arg_m]
# Out:
# 0.0

# %%
idx2 = []

for i in range(len(dist)):
    counter = 0
    for j in range(len(dist[i])):
        if dist[i][j] > sparest[max_min[-10]]:
            counter = counter + 1
    if counter > 4164:
        idx2.append(i)

# %%
len(idx2)
# Out:
# 718

# %%
sampled = AE[idx2]

# %%
plt.figure(figsize=(20,20))
plt.scatter(AE[:,0], AE[:,1])
plt.scatter(sampled[:,0], sampled[:,1], c= "red")

# %%
mean_dist[1572]
# Out:
# 82.986336

# %%
import matplotlib.pyplot as plt
plt.hist(mean_dist)
#plt.show()
# Out:
# (array([2403., 2209., 2175., 2158., 2256., 1862., 2385., 2139., 1074.,
#          267.]),
#  array([ 58.6469  ,  63.691277,  68.73565 ,  73.78002 ,  78.8244  ,
#          83.868774,  88.91315 ,  93.95752 ,  99.00189 , 104.04627 ,
#         109.090645], dtype=float32),
#  <a list of 10 Patch objects>)

# %%
np.save("sparsert_atom_feat.npy", idx2)

# %%
644+344+92+26+28+18
# Out:
# 1152

# %%
true_idx = np.load('./cgcnn-master/Indices/AE/AE_returned_idx/IDX_curr.npy')

# %%
true_sparse_1 = true_idx[idx]

# %%
np.save('sparse_AE_1396.npy', true_sparse_1)

# %% [markdown]
# ##### TSNE

# %%
tsne = np.load('tsne.npy', allow_pickle = True)

# %%
tsne

# %%
tsne_dist = np.linalg.norm(tsne - tsne[:,None], axis=-1)

# %%
tsne_mean_dist = np.mean(tsne_dist, axis = 1)

# %%
arg_m_tsne = np.argmax(tsne_mean_dist)

# %%
arg_m_tsne

# %%
sparest_tsne = tsne_dist[arg_m_tsne]

# %%
sparest_tsne

# %%
sparest_tsne[15127]

# %%
max_min_tsne = sparest_tsne.argsort()[-18928:][::-1]

# %%
max_min_tsne[-20:]

# %%
idx1 = []

for i in range(len(tsne_dist)):
    counter = 0
    for j in range(len(tsne_dist[i])):
        if tsne_dist[i][j] > sparest_tsne[16120]:
            counter = counter + 1
    if counter > 18915:
        idx1.append(i)

# %%
len(idx1)

# %%
sampled_tsne = tsne[idx]

# %%
plt.figure(figsize=(10,10))
plt.scatter(tsne[:,0], tsne[:,1])
plt.scatter(sampled_tsne[:,0], sampled_tsne[:,1], c= "red")

# %%
len(idx)

# %%
np.save("sparse_tsne_737",idx1)

# %%
np.save("sparse_tsne_1259",idx)

# %%
tsne_idx_sparse = tsne_mean_dist.argsort()[-1598:][::-1]

# %%
import matplotlib.pyplot as plt
plt.hist(tsne_mean_dist)

# %%
np.save('tsne_sparse_idx.npy', tsne_idx_sparse)
